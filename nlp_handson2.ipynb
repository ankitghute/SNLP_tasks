# %%
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('waiting')
# Out:
# 'wait'

# %%
stemmerporter.stem('raining')
# Out:
# 'rain'

# %%
stemmerporter.stem('morning')
# Out:
# 'morn'

# %%
stemmerporter.stem('craziness')
# Out:
# 'crazi'

# %%
from nltk.stem import LancasterStemmer
stemmerporter = LancasterStemmer()
stemmerporter.stem('craziness')
# Out:
# 'crazy'

# %%
from nltk.stem import RegexpStemmer
stemmerporter = RegexpStemmer('ing')
stemmerporter.stem('ringing')
# Out:
# 'r'

# %%
stemmerporter.stem('chilling')
# Out:
# 'chill'

# %%
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
frenchstemmer = SnowballStemmer('french')
frenchstemmer.stem('journaux')
# Out:
# 'journal'

# %%
frenchstemmer = SnowballStemmer('german')
frenchstemmer.stem('Singen')
# Out:
# 'sing'

# %% [markdown]
# # Homework Task

# %%
#inltk doesn't support windows 7
#import inltk
#inltk.download()
#pip install inltk

# %%
#Stemming paragraphs

from nltk.stem import PorterStemmer

stemer = PorterStemmer()
example = "Am quick brown fox jumps over a lazy dog"
example = [stemer.stem(token) for token in example.split(" ")]
print(" ".join(example))
# Out:
# Am quick brown fox jump over a lazi dog

# %%
#Task:Lemmatizer
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("caring",pos='v'))
# Out:
# care

# %%
print(lemmatizer.lemmatize("better"))
# Out:
# better

# %%
print(lemmatizer.lemmatize("better", pos='a'))
# Out:
# good

# %%
print(lemmatizer.lemmatize("went", pos='v'))
# Out:
# go

# %%
#Task:  Chinese Segmentation using JIEBA

import jieba
seg = jieba.cut('''魔方的最佳解决方案是指最短的解决方案。有两种常见的方法来衡量解决方案的长度
''', cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\ankit\AppData\Local\Temp\jieba.cache
# Loading model cost 4.736 seconds.
# Prefix dict has been built successfully.
# 魔方 的 最佳 最佳解 解决 解决方案 方案 是 指 最 短 的 解决 解决方案 方案 。 有 两种 常见 的 方法 来 衡量 解决 解决方案 方案 的 长度

# %%
# Task: Basic text processing Pipeline

sent = "On July 20, 1969, astronaut Neil Armstrong took one giant leap for mankind as he stepped onto the moon. Six Apollo missions were made to explore the moon between 1969 and 1972."
words = nltk.word_tokenize(sent)
print(words)
# Out:
# ['On', 'July', '20', ',', '1969', ',', 'astronaut', 'Neil', 'Armstrong', 'took', 'one', 'giant', 'leap', 'for', 'mankind', 'as', 'he', 'stepped', 'onto', 'the', 'moon', '.', 'Six', 'Apollo', 'missions', 'were', 'made', 'to', 'explore', 'the', 'moon', 'between', '1969', 'and', '1972', '.']

# %%
#Space exploration paragrapgh
text1='''Humans have always looked up into the night sky and dreamed about space.

In the latter half of the 20th century, rockets were developed that were powerful enough to overcome the force of gravity to reach orbital velocities, paving the way for space exploration to become a reality.

In the 1930s and 1940s, Nazi Germany saw the possibilities of using long-distance rockets as weapons. Late in World War II, London was attacked by 200-mile-range V-2 missiles, which arched 60 miles high over the English Channel at more than 3,500 miles per hour. After World War II, the United States and the Soviet Union created their own missile programs.'''
for text in text1:
    sentences = nltk.sent_tokenize(text1)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        print(words)
# Out:
# ['Humans', 'have', 'always', 'looked', 'up', 'into', 'the', 'night', 'sky', 'and', 'dreamed', 'about', 'space', '.']
# ['In', 'the', 'latter', 'half', 'of', 'the', '20th', 'century', ',', 'rockets', 'were', 'developed', 'that', 'were', 'powerful', 'enough', 'to', 'overcome', 'the', 'force', 'of', 'gravity', 'to', 'reach', 'orbital', 'velocities', ',', 'paving', 'the', 'way', 'for', 'space', 'exploration', 'to', 'become', 'a', 'reality', '.']
# ['In', 'the', '1930s', 'and', '1940s', ',', 'Nazi', 'Germany', 'saw', 'the', 'possibilities', 'of', 'using', 'long-distance', 'rockets', 'as', 'weapons', '.']
# ['Late', 'in', 'World', 'War', 'II', ',', 'London', 'was', 'attacked', 'by', '200-mile-range', 'V-2', 'missiles', ',', 'which', 'arched', '60', 'miles', 'high', 'over', 'the', 'English', 'Channel', 'at', 'more', 'than', '3,500', 'miles', 'per', 'hour', '.']
# ...
