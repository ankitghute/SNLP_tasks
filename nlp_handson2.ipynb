# %%
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('waiting')
# Out:
# 'wait'

# %%
stemmerporter.stem('raining')
# Out:
# 'rain'

# %%
stemmerporter.stem('morning')
# Out:
# 'morn'

# %%
stemmerporter.stem('craziness')
# Out:
# 'crazi'

# %%
from nltk.stem import LancasterStemmer
stemmerporter = LancasterStemmer()
stemmerporter.stem('craziness')
# Out:
# 'crazy'

# %%
from nltk.stem import RegexpStemmer
stemmerporter = RegexpStemmer('ing')
stemmerporter.stem('ringing')
# Out:
# 'r'

# %%
stemmerporter.stem('chilling')
# Out:
# 'chill'

# %%
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
frenchstemmer = SnowballStemmer('french')
frenchstemmer.stem('journaux')
# Out:
# 'journal'

# %%
frenchstemmer = SnowballStemmer('german')
frenchstemmer.stem('Singen')
# Out:
# 'sing'

# %% [markdown]
# # Homework Task

# %%
#import inltk
#inltk.download()
#from nltk import tokenize
# !pip install inltk
# Out:
# ...
#   ERROR: Could not find a version that satisfies the requirement torch>=1.0.0 (from fastai==1.0.57->inltk) (from versions: 0.1.2, 0.1.2.post1, 0.1.2.post2)
# ERROR: No matching distribution found for torch>=1.0.0 (from fastai==1.0.57->inltk)

# %%
#Stemming paragraphs

from nltk.stem import PorterStemmer

stemer = PorterStemmer()
example = "Am quick brown fox jumps over a lazy dog"
example = [stemer.stem(token) for token in example.split(" ")]
print(" ".join(example))
# Out:
# Am quick brown fox jump over a lazi dog

# %%
#Task:Lemmatizer
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("caring",pos='v'))
# Out:
# care

# %%
print(lemmatizer.lemmatize("better"))
# Out:
# better

# %%
print(lemmatizer.lemmatize("better", pos='a'))
# Out:
# good

# %%
print(lemmatizer.lemmatize("went", pos='v'))
# Out:
# go

# %%
#Task:  Chinese Segmentation using JIEBA

import jieba
seg = jieba.cut('''魔方的最佳解决方案是指最短的解决方案。有两种常见的方法来衡量解决方案的长度
''', cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\ankit\AppData\Local\Temp\jieba.cache
# Loading model cost 4.736 seconds.
# Prefix dict has been built successfully.
# 魔方 的 最佳 最佳解 解决 解决方案 方案 是 指 最 短 的 解决 解决方案 方案 。 有 两种 常见 的 方法 来 衡量 解决 解决方案 方案 的 长度

# %%
# Task: Basic text processing Pipeline

sent = "Optimal solution for Rubik's Cube refer to solutions that are the shortest. There are two common ways to measure the length of a solution"
words = nltk.word_tokenize(sent)
print(words)
# Out:
# ['Optimal', 'solution', 'for', 'Rubik', "'s", 'Cube', 'refer', 'to', 'solutions', 'that', 'are', 'the', 'shortest', '.', 'There', 'are', 'two', 'common', 'ways', 'to', 'measure', 'the', 'length', 'of', 'a', 'solution']

# %%
for text in text1:
    sentences = nltk.sent_tokenize(text1)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = nltk.pos(words)
        print(tagged)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-28b5edfd4adb> in <module>
#       3     for sentence in sentences:
#       4         words = nltk.word_tokenize(sentence)
# ----> 5         tagged = nltk.pos(words)
#       6         print(tagged)
#
# AttributeError: module 'nltk' has no attribute 'pos'

# %%
text1 = '''In 2006, Silviu Radu further improved his methods to prove that every position can be solved in at most 27 face turns or 35 quarter turns.[17] Daniel Kunkle and Gene Cooperman in 2007 used a supercomputer to show that all unsolved cubes can be solved in no more than 26 moves (in face-turn metric). Instead of attempting to solve each of the billions of variations explicitly, the computer was programmed to bring the cube to one of 15,752 states, each of which could be solved within a few extra moves. All were proved solvable in 29 moves, with most solvable in 26. Those that could not initially be solved in 26 moves were then solved explicitly, and shown that they too could be solved in 26 moves.[18][19]

Tomas Rokicki reported in a 2008 computational proof that all unsolved cubes could be solved in 25 moves or fewer.[20] This was later reduced to 23 moves.[21] In August 2008 Rokicki announced that he had a proof for 22 moves.[22]

Finally, in 2010, Tomas Rokicki, Herbert Kociemba, Morley Davidson, and John Dethridge gave the final computer-assisted proof that all cube positions could be solved with a maximum of 20 face turns.[2] In 2009, Tomas Rokicki proved that 29 moves in the quarter-turn metric is enough to solve any scrambled cube.[23] And in 2014, Tomas Rokicki and Morley Davidson proved that the maximum number of quarter-turns needed to solve the cube is 26.[3]'''
for text in text1:
    sentences = nltk.sent_tokenize(text1)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        print(words)
# Out:
# ['In', '2006', ',', 'Silviu', 'Radu', 'further', 'improved', 'his', 'methods', 'to', 'prove', 'that', 'every', 'position', 'can', 'be', 'solved', 'in', 'at', 'most', '27', 'face', 'turns', 'or', '35', 'quarter', 'turns', '.']
# ['[', '17', ']', 'Daniel', 'Kunkle', 'and', 'Gene', 'Cooperman', 'in', '2007', 'used', 'a', 'supercomputer', 'to', 'show', 'that', 'all', 'unsolved', 'cubes', 'can', 'be', 'solved', 'in', 'no', 'more', 'than', '26', 'moves', '(', 'in', 'face-turn', 'metric', ')', '.']
# ['Instead', 'of', 'attempting', 'to', 'solve', 'each', 'of', 'the', 'billions', 'of', 'variations', 'explicitly', ',', 'the', 'computer', 'was', 'programmed', 'to', 'bring', 'the', 'cube', 'to', 'one', 'of', '15,752', 'states', ',', 'each', 'of', 'which', 'could', 'be', 'solved', 'within', 'a', 'few', 'extra', 'moves', '.']
# ['All', 'were', 'proved', 'solvable', 'in', '29', 'moves', ',', 'with', 'most', 'solvable', 'in', '26', '.']
# ...
